# %%
import pandas as pd


csv_path = "subject-1.csv"

trial_data = pd.read_csv(csv_path)

# %%
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]
display(trial_data_gezeigt)
# Out:
#                   AN Code                           RN        acc   accuracy  \
# 0    <AN>Frauen</AN>   C4   <RN>Krankenschwestern</RN>  undefined  undefined
# 8    <AN>Frauen</AN>   C4    <RN>Unternehmerinnen</RN>  undefined  undefined
# 9    <AN>Frauen</AN>   C2            <RN>Experten</RN>  undefined  undefined
# 10   <AN>Frauen</AN>   C2           <RN>Einwohner</RN>  undefined  undefined
# 11   <AN>Frauen</AN>   C6      <RN>Polizist*innen</RN>  undefined  undefined
# 16   <AN>Männer</AN>   C5      <RN>Aktivist*innen</RN>  undefined  undefined
# 19   <AN>Männer</AN>   C3         <RN>Dozentinnen</RN>  undefined  undefined
# 25   <AN>Frauen</AN>   C6        <RN>Lehrer*innen</RN>  undefined  undefined
# 28  <AN>Männern</AN>   C1           <RN>Einwohner</RN>  undefined  undefined
# 29   <AN>Männer</AN>   C1           <RN>Studenten</RN>  undefined  undefined
# 44   <AN>Männer</AN>   C3      <RN>Ingenieurinnen</RN>  undefined  undefined
# 46   <AN>Frauen</AN>   C4         <RN>Expertinnen</RN>  undefined  undefined
# 73   <AN>Männer</AN>   C3      <RN>Professorinnen</RN>  undefined  undefined
# 74   <AN>Männer</AN>   C5  <RN>Arbeitnehmer*innen</RN>  undefined  undefined
# 76   <AN>Männer</AN>   C1            <RN>Experten</RN>  undefined  undefined
# 81   <AN>Frauen</AN>   C6  <RN>Arbeitnehmer*innen</RN>  undefined  undefined
# 87   <AN>Männer</AN>   C5     <RN>Ingenieur*innen</RN>  undefined  undefined
# 91   <AN>Frauen</AN>   C2             <RN>Pfleger</RN>  undefined  undefined
#
#     an_found  an_height  an_line           an_text  an_width  ...       title  \
# 0       True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 8       True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 9       True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 10      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 11      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 16      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 19      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 25      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 28      True         53        4  <AN>Männern</AN>       158  ...  Experiment
# 29      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 44      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 46      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 73      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 74      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 76      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 81      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
# 87      True         53        4   <AN>Männer</AN>       135  ...  Experiment
# 91      True         53        4   <AN>Frauen</AN>       132  ...  Experiment
#
#     total_correct  total_response_time  total_responses trial_counter width  \
# 0               0                    0                0             1  1920
# 8               0                    0                0             2  1920
# 9               0                    0                0             3  1920
# 10              0                    0                0             4  1920
# 11              0                    0                0             5  1920
# 16              0                    0                0             6  1920
# 19              0                    0                0             7  1920
# 25              0                    0                0             8  1920
# 28              0                    0                0             9  1920
# 29              0                    0                0            10  1920
# 44              0                    0                0            11  1920
# 46              0                    0                0            12  1920
# 73              0                    0                0            13  1920
# 74              0                    0                0            14  1920
# 76              0                    0                0            15  1920
# 81              0                    0                0            16  1920
# 87              0                    0                0            17  1920
# 91              0                    0                0            18  1920
#
#              word  word_height word_spacing  word_width
# 0     diskutiert.           53           25         243
# 8     umstritten.           53           25         243
# 9       bewertet.           53           25         197
# 10    Reaktionen.           53           25         242
# 11    verhandelt.           53           25         244
# 16       geprüft.           53           25         175
# 19            an.           53           25          59
# 25  Diskussionen.           53           25         289
# 28      Debatten.           53           25         197
# 29      Debatten.           53           25         197
# 44    gestritten.           53           25         244
# 46       geprüft.           53           25         175
# 73    diskutiert.           53           25         243
# 74         offen.           53           25         129
# 76      bewertet.           53           25         197
# 81  Diskussionen.           53           25         289
# 87    diskutiert.           53           25         243
# 91    diskutiert.           53           25         243
#
# [18 rows x 150 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Gewünschte Spalten
spalten = [
    "Code","AN", "RN",
    "an_found", "an_height", "an_line", "an_width",
    "an_x1", "an_x2",
    "current_line", "current_line_width",
    "datetime",
    "display_sentence",
    "experiment_file", "experiment_path",
    "item",
    "name",
    "rn_found", "rn_height", "rn_line", "rn_text",
    "rn_width", "rn_x1", "rn_x2", "rn_y1", "rn_y2",
    "selected_list",
    "skip_trial",
    "spill_x1", "spill_x2", "spill_y1", "spill_y2",
    "trial_counter"
]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

display(trial_data_auswahl)
# Out:
#    Code                AN                           RN  an_found  an_height  \
# 0    C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>      True         53
# 8    C4   <AN>Frauen</AN>    <RN>Unternehmerinnen</RN>      True         53
# 9    C2   <AN>Frauen</AN>            <RN>Experten</RN>      True         53
# 10   C2   <AN>Frauen</AN>           <RN>Einwohner</RN>      True         53
# 11   C6   <AN>Frauen</AN>      <RN>Polizist*innen</RN>      True         53
# 16   C5   <AN>Männer</AN>      <RN>Aktivist*innen</RN>      True         53
# 19   C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>      True         53
# 25   C6   <AN>Frauen</AN>        <RN>Lehrer*innen</RN>      True         53
# 28   C1  <AN>Männern</AN>           <RN>Einwohner</RN>      True         53
# 29   C1   <AN>Männer</AN>           <RN>Studenten</RN>      True         53
# 44   C3   <AN>Männer</AN>      <RN>Ingenieurinnen</RN>      True         53
# 46   C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>      True         53
# 73   C3   <AN>Männer</AN>      <RN>Professorinnen</RN>      True         53
# 74   C5   <AN>Männer</AN>  <RN>Arbeitnehmer*innen</RN>      True         53
# 76   C1   <AN>Männer</AN>            <RN>Experten</RN>      True         53
# 81   C6   <AN>Frauen</AN>  <RN>Arbeitnehmer*innen</RN>      True         53
# 87   C5   <AN>Männer</AN>     <RN>Ingenieur*innen</RN>      True         53
# 91   C2   <AN>Frauen</AN>             <RN>Pfleger</RN>      True         53
#
#     an_line  an_width  an_x1  an_x2  current_line  ...  rn_x2  rn_y1  rn_y2  \
# 0         4       132 -131.0    1.0             5  ...  756.0 -173.0 -120.0
# 8         4       132  -84.0   48.0             5  ... -446.0  -56.0   -3.0
# 9         4       132 -223.0  -91.0             5  ... -631.0  -56.0   -3.0
# 10        4       132 -179.0  -47.0             5  ... -608.0  -56.0   -3.0
# 11        4       132 -202.0  -70.0             5  ...  304.0 -173.0 -120.0
# 16        4       135 -201.0  -66.0             5  ...  581.0 -173.0 -120.0
# 19        4       135 -339.0 -204.0             5  ...  737.0 -173.0 -120.0
# 25        4       132 -333.0 -201.0             5  ...  231.0 -173.0 -120.0
# 28        4       158 -309.0 -151.0             5  ... -608.0  -56.0   -3.0
# 29        4       135 -378.0 -243.0             5  ...  327.0 -173.0 -120.0
# 44        4       135 -130.0    5.0             5  ... -494.0  -56.0   -3.0
# 46        4       132  -63.0   69.0             5  ... -403.0  -56.0   -3.0
# 73        4       135  -65.0   70.0             5  ...  778.0 -173.0 -120.0
# 74        4       135 -220.0  -85.0             5  ... -398.0  -56.0   -3.0
# 76        4       135 -309.0 -174.0             5  ... -631.0  -56.0   -3.0
# 81        4       132 -105.0   27.0             6  ... -398.0  -56.0   -3.0
# 87        4       135  365.0  500.0             6  ... -471.0  -56.0   -3.0
# 91        4       132 -222.0  -90.0             6  ...  737.0 -173.0 -120.0
#
#    selected_list skip_trial  spill_x1 spill_x2  spill_y1  spill_y2  \
# 0              1          0       1.0    133.0      61.0     114.0
# 8              1          0      48.0    180.0      61.0     114.0
# 9              1          0     -91.0     41.0      61.0     114.0
# 10             1          0     -47.0     85.0      61.0     114.0
# 11             1          0     -70.0     62.0      61.0     114.0
# 16             1          0     -66.0     69.0      61.0     114.0
# 19             1          0    -204.0    -69.0      61.0     114.0
# 25             1          0    -201.0    -69.0      61.0     114.0
# 28             1          0    -151.0      7.0      61.0     114.0
# 29             1          0    -243.0   -108.0      61.0     114.0
# 44             1          0       5.0    140.0      61.0     114.0
# 46             1          0      69.0    201.0      61.0     114.0
# 73             1          0      70.0    205.0      61.0     114.0
# 74             1          0     -85.0     50.0      61.0     114.0
# 76             1          0    -174.0    -39.0      61.0     114.0
# 81             1          0      27.0    159.0      61.0     114.0
# 87             1          0     500.0    635.0      61.0     114.0
# 91             1          0     -90.0     42.0      61.0     114.0
#
#     trial_counter
# 0               1
# 8               2
# 9               3
# 10              4
# 11              5
# 16              6
# 19              7
# 25              8
# 28              9
# 29             10
# 44             11
# 46             12
# 73             13
# 74             14
# 76             15
# 81             16
# 87             17
# 91             18
#
# [18 rows x 33 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

# Nach Code sortieren
trial_data_auswahl = trial_data_auswahl.sort_values(by="Code")

display(trial_data_auswahl)
# Out:
#    Code                AN                           RN  an_found  an_height  \
# 28   C1  <AN>Männern</AN>           <RN>Einwohner</RN>      True         53
# 76   C1   <AN>Männer</AN>            <RN>Experten</RN>      True         53
# 29   C1   <AN>Männer</AN>           <RN>Studenten</RN>      True         53
# 91   C2   <AN>Frauen</AN>             <RN>Pfleger</RN>      True         53
# 9    C2   <AN>Frauen</AN>            <RN>Experten</RN>      True         53
# 10   C2   <AN>Frauen</AN>           <RN>Einwohner</RN>      True         53
# 19   C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>      True         53
# 44   C3   <AN>Männer</AN>      <RN>Ingenieurinnen</RN>      True         53
# 73   C3   <AN>Männer</AN>      <RN>Professorinnen</RN>      True         53
# 46   C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>      True         53
# 8    C4   <AN>Frauen</AN>    <RN>Unternehmerinnen</RN>      True         53
# 0    C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>      True         53
# 16   C5   <AN>Männer</AN>      <RN>Aktivist*innen</RN>      True         53
# 87   C5   <AN>Männer</AN>     <RN>Ingenieur*innen</RN>      True         53
# 74   C5   <AN>Männer</AN>  <RN>Arbeitnehmer*innen</RN>      True         53
# 11   C6   <AN>Frauen</AN>      <RN>Polizist*innen</RN>      True         53
# 25   C6   <AN>Frauen</AN>        <RN>Lehrer*innen</RN>      True         53
# 81   C6   <AN>Frauen</AN>  <RN>Arbeitnehmer*innen</RN>      True         53
#
#     an_x1  an_x2  item  rn_height  rn_line  ...  rn_x2  rn_y1  rn_y2  \
# 28 -309.0 -151.0    13         53        3  ... -608.0  -56.0   -3.0
# 76 -309.0 -174.0     7         53        3  ... -631.0  -56.0   -3.0
# 29 -378.0 -243.0     1         53        2  ...  327.0 -173.0 -120.0
# 91 -222.0  -90.0     2         53        2  ...  737.0 -173.0 -120.0
# 9  -223.0  -91.0    14         53        3  ... -631.0  -56.0   -3.0
# 10 -179.0  -47.0     8         53        3  ... -608.0  -56.0   -3.0
# 19 -339.0 -204.0     9         53        2  ...  737.0 -173.0 -120.0
# 44 -130.0    5.0     3         53        3  ... -494.0  -56.0   -3.0
# 73  -65.0   70.0    15         53        2  ...  778.0 -173.0 -120.0
# 46  -63.0   69.0    10         53        3  ... -403.0  -56.0   -3.0
# 8   -84.0   48.0     4         53        3  ... -446.0  -56.0   -3.0
# 0  -131.0    1.0    16         53        2  ...  756.0 -173.0 -120.0
# 16 -201.0  -66.0    11         53        2  ...  581.0 -173.0 -120.0
# 87  365.0  500.0    17         53        3  ... -471.0  -56.0   -3.0
# 74 -220.0  -85.0     5         53        3  ... -398.0  -56.0   -3.0
# 11 -202.0  -70.0    18         53        2  ...  304.0 -173.0 -120.0
# 25 -333.0 -201.0     6         53        2  ...  231.0 -173.0 -120.0
# 81 -105.0   27.0    12         53        3  ... -398.0  -56.0   -3.0
#
#     selected_list  skip_trial  spill_x1  spill_x2  spill_y1  spill_y2  \
# 28              1           0    -151.0       7.0      61.0     114.0
# 76              1           0    -174.0     -39.0      61.0     114.0
# 29              1           0    -243.0    -108.0      61.0     114.0
# 91              1           0     -90.0      42.0      61.0     114.0
# 9               1           0     -91.0      41.0      61.0     114.0
# 10              1           0     -47.0      85.0      61.0     114.0
# 19              1           0    -204.0     -69.0      61.0     114.0
# 44              1           0       5.0     140.0      61.0     114.0
# 73              1           0      70.0     205.0      61.0     114.0
# 46              1           0      69.0     201.0      61.0     114.0
# 8               1           0      48.0     180.0      61.0     114.0
# 0               1           0       1.0     133.0      61.0     114.0
# 16              1           0     -66.0      69.0      61.0     114.0
# 87              1           0     500.0     635.0      61.0     114.0
# 74              1           0     -85.0      50.0      61.0     114.0
# 11              1           0     -70.0      62.0      61.0     114.0
# 25              1           0    -201.0     -69.0      61.0     114.0
# 81              1           0      27.0     159.0      61.0     114.0
#
#     trial_counter
# 28              9
# 76             15
# 29             10
# 91             18
# 9               3
# 10              4
# 19              7
# 44             11
# 73             13
# 46             12
# 8               2
# 0               1
# 16              6
# 87             17
# 74             14
# 11              5
# 25              8
# 81             16
#
# [18 rows x 23 columns]
