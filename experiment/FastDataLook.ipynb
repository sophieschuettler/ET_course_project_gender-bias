# %%
import pandas as pd


csv_path = "../data/raw/subject-1.csv"

trial_data = pd.read_csv(csv_path)

# %%
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]
display(trial_data_gezeigt)
# Out:
#                    AN Code                           RN        acc   accuracy  \
# 1     <AN>Frauen</AN>   C4   <RN>Krankenschwestern</RN>  undefined  undefined
# 6     <AN>Frauen</AN>   C2             <RN>Pfleger</RN>  undefined  undefined
# 11    <AN>Frauen</AN>   C2            <RN>Experten</RN>  undefined  undefined
# 14    <AN>Frauen</AN>   C2           <RN>Einwohner</RN>  undefined  undefined
# 21    <AN>Männer</AN>   C5  <RN>Arbeitnehmer*innen</RN>  undefined  undefined
# 24    <AN>Frauen</AN>   C6      <RN>Polizist*innen</RN>  undefined  undefined
# 33    <AN>Frauen</AN>   C4    <RN>Unternehmerinnen</RN>  undefined  undefined
# 43    <AN>Männer</AN>   C5     <RN>Ingenieur*innen</RN>  undefined  undefined
# 44   <AN>Männern</AN>   C1           <RN>Einwohner</RN>  undefined  undefined
# 51    <AN>Männer</AN>   C1            <RN>Experten</RN>  undefined  undefined
# 64    <AN>Männer</AN>   C5      <RN>Aktivist*innen</RN>  undefined  undefined
# 65    <AN>Männer</AN>   C3         <RN>Dozentinnen</RN>  undefined  undefined
# 68    <AN>Männer</AN>   C3      <RN>Professorinnen</RN>  undefined  undefined
# 77    <AN>Frauen</AN>   C6        <RN>Lehrer*innen</RN>  undefined  undefined
# 95    <AN>Männer</AN>   C1           <RN>Studenten</RN>  undefined  undefined
# 97    <AN>Frauen</AN>   C6  <RN>Arbeitnehmer*innen</RN>  undefined  undefined
# 98    <AN>Frauen</AN>   C4         <RN>Expertinnen</RN>  undefined  undefined
# 100   <AN>Männer</AN>   C3      <RN>Ingenieurinnen</RN>  undefined  undefined
#
#     an_found  an_height  an_line           an_text  an_width  ...       title  \
# 1       True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 6       True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 11      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 14      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 21      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 24      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 33      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 43      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 44      True       53.0      4.0  <AN>Männern</AN>     158.0  ...  Experiment
# 51      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 64      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 65      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 68      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 77      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 95      True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
# 97      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 98      True       53.0      4.0   <AN>Frauen</AN>     132.0  ...  Experiment
# 100     True       53.0      4.0   <AN>Männer</AN>     135.0  ...  Experiment
#
#      total_correct  total_response_time  total_responses trial_counter width  \
# 1                0                    0                0             1  1920
# 6                0                    0                0             2  1920
# 11               0                    0                0             3  1920
# 14               0                    0                0             4  1920
# 21               0                    0                0             5  1920
# 24               0                    0                0             6  1920
# 33               0                    0                0             7  1920
# 43               0                    0                0             8  1920
# 44               0                    0                0             9  1920
# 51               0                    0                0            10  1920
# 64               0                    0                0            11  1920
# 65               0                    0                0            12  1920
# 68               0                    0                0            13  1920
# 77               0                    0                0            14  1920
# 95               0                    0                0            15  1920
# 97               0                    0                0            16  1920
# 98               0                    0                0            17  1920
# 100              0                    0                0            18  1920
#
#               word  word_height word_spacing word_width
# 1      diskutiert.         53.0         25.0      243.0
# 6      diskutiert.         53.0         25.0      243.0
# 11       bewertet.         53.0         25.0      197.0
# 14     Reaktionen.         53.0         25.0      242.0
# 21          offen.         53.0         25.0      129.0
# 24     verhandelt.         53.0         25.0      244.0
# 33     umstritten.         53.0         25.0      243.0
# 43     diskutiert.         53.0         25.0      243.0
# 44       Debatten.         53.0         25.0      197.0
# 51       bewertet.         53.0         25.0      197.0
# 64        geprüft.         53.0         25.0      175.0
# 65             an.         53.0         25.0       59.0
# 68     diskutiert.         53.0         25.0      243.0
# 77   Diskussionen.         53.0         25.0      289.0
# 95       Debatten.         53.0         25.0      197.0
# 97   Diskussionen.         53.0         25.0      289.0
# 98        geprüft.         53.0         25.0      175.0
# 100    gestritten.         53.0         25.0      244.0
#
# [18 rows x 150 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Gewünschte Spalten
spalten = [
    "Code","AN", "RN",
    "an_found", "an_height", "an_line", "an_width",
    "an_x1", "an_x2",
    "current_line", "current_line_width",
    "datetime",
    "display_sentence",
    "experiment_file", "experiment_path",
    "item",
    "name",
    "rn_found", "rn_height", "rn_line", "rn_text",
    "rn_width", "rn_x1", "rn_x2", "rn_y1", "rn_y2",
    "selected_list",
    "skip_trial",
    "spill_x1", "spill_x2", "spill_y1", "spill_y2",
    "trial_counter"
]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

display(trial_data_auswahl)
# Out:
#     Code                AN                           RN an_found  an_height  \
# 1     C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>     True       53.0
# 6     C2   <AN>Frauen</AN>             <RN>Pfleger</RN>     True       53.0
# 11    C2   <AN>Frauen</AN>            <RN>Experten</RN>     True       53.0
# 14    C2   <AN>Frauen</AN>           <RN>Einwohner</RN>     True       53.0
# 21    C5   <AN>Männer</AN>  <RN>Arbeitnehmer*innen</RN>     True       53.0
# 24    C6   <AN>Frauen</AN>      <RN>Polizist*innen</RN>     True       53.0
# 33    C4   <AN>Frauen</AN>    <RN>Unternehmerinnen</RN>     True       53.0
# 43    C5   <AN>Männer</AN>     <RN>Ingenieur*innen</RN>     True       53.0
# 44    C1  <AN>Männern</AN>           <RN>Einwohner</RN>     True       53.0
# 51    C1   <AN>Männer</AN>            <RN>Experten</RN>     True       53.0
# 64    C5   <AN>Männer</AN>      <RN>Aktivist*innen</RN>     True       53.0
# 65    C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>     True       53.0
# 68    C3   <AN>Männer</AN>      <RN>Professorinnen</RN>     True       53.0
# 77    C6   <AN>Frauen</AN>        <RN>Lehrer*innen</RN>     True       53.0
# 95    C1   <AN>Männer</AN>           <RN>Studenten</RN>     True       53.0
# 97    C6   <AN>Frauen</AN>  <RN>Arbeitnehmer*innen</RN>     True       53.0
# 98    C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>     True       53.0
# 100   C3   <AN>Männer</AN>      <RN>Ingenieurinnen</RN>     True       53.0
#
#      an_line  an_width  an_x1  an_x2  current_line  ...  rn_x2  rn_y1  rn_y2  \
# 1        4.0     132.0 -131.0    1.0           5.0  ...  756.0 -173.0 -120.0
# 6        4.0     132.0 -222.0  -90.0           6.0  ...  737.0 -173.0 -120.0
# 11       4.0     132.0 -223.0  -91.0           5.0  ... -631.0  -56.0   -3.0
# 14       4.0     132.0 -179.0  -47.0           5.0  ... -608.0  -56.0   -3.0
# 21       4.0     135.0 -220.0  -85.0           5.0  ... -398.0  -56.0   -3.0
# 24       4.0     132.0 -202.0  -70.0           5.0  ...  304.0 -173.0 -120.0
# 33       4.0     132.0  -84.0   48.0           5.0  ... -446.0  -56.0   -3.0
# 43       4.0     135.0  115.0  250.0           5.0  ... -471.0  -56.0   -3.0
# 44       4.0     158.0 -309.0 -151.0           5.0  ... -608.0  -56.0   -3.0
# 51       4.0     135.0 -309.0 -174.0           5.0  ... -631.0  -56.0   -3.0
# 64       4.0     135.0 -201.0  -66.0           5.0  ...  581.0 -173.0 -120.0
# 65       4.0     135.0 -339.0 -204.0           5.0  ...  737.0 -173.0 -120.0
# 68       4.0     135.0  -65.0   70.0           5.0  ...  778.0 -173.0 -120.0
# 77       4.0     132.0 -333.0 -201.0           5.0  ...  231.0 -173.0 -120.0
# 95       4.0     135.0 -378.0 -243.0           5.0  ...  327.0 -173.0 -120.0
# 97       4.0     132.0 -105.0   27.0           6.0  ... -398.0  -56.0   -3.0
# 98       4.0     132.0  -63.0   69.0           5.0  ... -403.0  -56.0   -3.0
# 100      4.0     135.0 -130.0    5.0           5.0  ... -494.0  -56.0   -3.0
#
#     selected_list skip_trial  spill_x1 spill_x2 spill_y1  spill_y2  \
# 1               1          0       1.0    133.0     61.0     114.0
# 6               1          0     -90.0     42.0     61.0     114.0
# 11              1          0     -91.0     41.0     61.0     114.0
# 14              1          0     -47.0     85.0     61.0     114.0
# 21              1          0     -85.0     50.0     61.0     114.0
# 24              1          0     -70.0     62.0     61.0     114.0
# 33              1          0      48.0    180.0     61.0     114.0
# 43              1          0     250.0    385.0     61.0     114.0
# 44              1          0    -151.0      7.0     61.0     114.0
# 51              1          0    -174.0    -39.0     61.0     114.0
# 64              1          0     -66.0     69.0     61.0     114.0
# 65              1          0    -204.0    -69.0     61.0     114.0
# 68              1          0      70.0    205.0     61.0     114.0
# 77              1          0    -201.0    -69.0     61.0     114.0
# 95              1          0    -243.0   -108.0     61.0     114.0
# 97              1          0      27.0    159.0     61.0     114.0
# 98              1          0      69.0    201.0     61.0     114.0
# 100             1          0       5.0    140.0     61.0     114.0
#
#      trial_counter
# 1                1
# 6                2
# 11               3
# 14               4
# 21               5
# 24               6
# 33               7
# 43               8
# 44               9
# 51              10
# 64              11
# 65              12
# 68              13
# 77              14
# 95              15
# 97              16
# 98              17
# 100             18
#
# [18 rows x 33 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

# Nach Code sortieren
trial_data_auswahl = trial_data_auswahl.sort_values(by="Code")

display(trial_data_auswahl)
# Out:
#     Code                AN                           RN an_found  an_height  \
# 44    C1  <AN>Männern</AN>           <RN>Einwohner</RN>     True       53.0
# 95    C1   <AN>Männer</AN>           <RN>Studenten</RN>     True       53.0
# 51    C1   <AN>Männer</AN>            <RN>Experten</RN>     True       53.0
# 6     C2   <AN>Frauen</AN>             <RN>Pfleger</RN>     True       53.0
# 11    C2   <AN>Frauen</AN>            <RN>Experten</RN>     True       53.0
# 14    C2   <AN>Frauen</AN>           <RN>Einwohner</RN>     True       53.0
# 68    C3   <AN>Männer</AN>      <RN>Professorinnen</RN>     True       53.0
# 65    C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>     True       53.0
# 100   C3   <AN>Männer</AN>      <RN>Ingenieurinnen</RN>     True       53.0
# 33    C4   <AN>Frauen</AN>    <RN>Unternehmerinnen</RN>     True       53.0
# 98    C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>     True       53.0
# 1     C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>     True       53.0
# 43    C5   <AN>Männer</AN>     <RN>Ingenieur*innen</RN>     True       53.0
# 64    C5   <AN>Männer</AN>      <RN>Aktivist*innen</RN>     True       53.0
# 21    C5   <AN>Männer</AN>  <RN>Arbeitnehmer*innen</RN>     True       53.0
# 24    C6   <AN>Frauen</AN>      <RN>Polizist*innen</RN>     True       53.0
# 77    C6   <AN>Frauen</AN>        <RN>Lehrer*innen</RN>     True       53.0
# 97    C6   <AN>Frauen</AN>  <RN>Arbeitnehmer*innen</RN>     True       53.0
#
#      an_line  an_width  an_x1  an_x2  current_line  ...  rn_x2  rn_y1  rn_y2  \
# 44       4.0     158.0 -309.0 -151.0           5.0  ... -608.0  -56.0   -3.0
# 95       4.0     135.0 -378.0 -243.0           5.0  ...  327.0 -173.0 -120.0
# 51       4.0     135.0 -309.0 -174.0           5.0  ... -631.0  -56.0   -3.0
# 6        4.0     132.0 -222.0  -90.0           6.0  ...  737.0 -173.0 -120.0
# 11       4.0     132.0 -223.0  -91.0           5.0  ... -631.0  -56.0   -3.0
# 14       4.0     132.0 -179.0  -47.0           5.0  ... -608.0  -56.0   -3.0
# 68       4.0     135.0  -65.0   70.0           5.0  ...  778.0 -173.0 -120.0
# 65       4.0     135.0 -339.0 -204.0           5.0  ...  737.0 -173.0 -120.0
# 100      4.0     135.0 -130.0    5.0           5.0  ... -494.0  -56.0   -3.0
# 33       4.0     132.0  -84.0   48.0           5.0  ... -446.0  -56.0   -3.0
# 98       4.0     132.0  -63.0   69.0           5.0  ... -403.0  -56.0   -3.0
# 1        4.0     132.0 -131.0    1.0           5.0  ...  756.0 -173.0 -120.0
# 43       4.0     135.0  115.0  250.0           5.0  ... -471.0  -56.0   -3.0
# 64       4.0     135.0 -201.0  -66.0           5.0  ...  581.0 -173.0 -120.0
# 21       4.0     135.0 -220.0  -85.0           5.0  ... -398.0  -56.0   -3.0
# 24       4.0     132.0 -202.0  -70.0           5.0  ...  304.0 -173.0 -120.0
# 77       4.0     132.0 -333.0 -201.0           5.0  ...  231.0 -173.0 -120.0
# 97       4.0     132.0 -105.0   27.0           6.0  ... -398.0  -56.0   -3.0
#
#     selected_list skip_trial  spill_x1 spill_x2 spill_y1  spill_y2  \
# 44              1          0    -151.0      7.0     61.0     114.0
# 95              1          0    -243.0   -108.0     61.0     114.0
# 51              1          0    -174.0    -39.0     61.0     114.0
# 6               1          0     -90.0     42.0     61.0     114.0
# 11              1          0     -91.0     41.0     61.0     114.0
# 14              1          0     -47.0     85.0     61.0     114.0
# 68              1          0      70.0    205.0     61.0     114.0
# 65              1          0    -204.0    -69.0     61.0     114.0
# 100             1          0       5.0    140.0     61.0     114.0
# 33              1          0      48.0    180.0     61.0     114.0
# 98              1          0      69.0    201.0     61.0     114.0
# 1               1          0       1.0    133.0     61.0     114.0
# 43              1          0     250.0    385.0     61.0     114.0
# 64              1          0     -66.0     69.0     61.0     114.0
# 21              1          0     -85.0     50.0     61.0     114.0
# 24              1          0     -70.0     62.0     61.0     114.0
# 77              1          0    -201.0    -69.0     61.0     114.0
# 97              1          0      27.0    159.0     61.0     114.0
#
#      trial_counter
# 44               9
# 95              15
# 51              10
# 6                2
# 11               3
# 14               4
# 68              13
# 65              12
# 100             18
# 33               7
# 98              17
# 1                1
# 43               8
# 64              11
# 21               5
# 24               6
# 77              14
# 97              16
#
# [18 rows x 33 columns]
