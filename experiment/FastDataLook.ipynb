# %%
import pandas as pd


csv_path = "subject-3.csv"

trial_data = pd.read_csv(csv_path)

# %%
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]
display(trial_data_gezeigt)
# Out:
#                    AN Code                           RN        acc   accuracy  \
# 7     <AN>Frauen</AN>   C2            <RN>Experten</RN>  undefined  undefined
# 15    <AN>Frauen</AN>   C6      <RN>Polizist*innen</RN>  undefined  undefined
# 16    <AN>Frauen</AN>   C2           <RN>Einwohner</RN>  undefined  undefined
# 20    <AN>Männer</AN>   C5      <RN>Aktivist*innen</RN>  undefined  undefined
# 31    <AN>Männer</AN>   C5  <RN>Arbeitnehmer*innen</RN>  undefined  undefined
# 34    <AN>Frauen</AN>   C4   <RN>Krankenschwestern</RN>  undefined  undefined
# 36    <AN>Frauen</AN>   C4         <RN>Expertinnen</RN>  undefined  undefined
# 38    <AN>Männer</AN>   C5     <RN>Ingenieur*innen</RN>  undefined  undefined
# 40    <AN>Männer</AN>   C3      <RN>Professorinnen</RN>  undefined  undefined
# 43    <AN>Männer</AN>   C3         <RN>Dozentinnen</RN>  undefined  undefined
# 47   <AN>Männern</AN>   C1           <RN>Einwohner</RN>  undefined  undefined
# ...

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Gewünschte Spalten
spalten = [
    "Code","AN", "RN",
    "an_found", "an_height", "an_line", "an_text", "an_width",
    "an_x1", "an_x2",
    "current_line", "current_line_width",
    "datetime",
    "display_sentence",
    "experiment_file", "experiment_path",
    "item",
    "name",
    "rn_found", "rn_height", "rn_line", "rn_text",
    "rn_width", "rn_x1", "rn_x2", "rn_y1", "rn_y2",
    "selected_list",
    "sentence",
    "skip_trial",
    "spill_x1", "spill_x2", "spill_y1", "spill_y2",
    "trial_counter"
]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

display(trial_data_auswahl)
# Out:
#     Code                AN                           RN an_found  an_height  \
# 7     C2   <AN>Frauen</AN>            <RN>Experten</RN>     True       53.0
# 15    C6   <AN>Frauen</AN>      <RN>Polizist*innen</RN>     True       53.0
# 16    C2   <AN>Frauen</AN>           <RN>Einwohner</RN>     True       53.0
# 20    C5   <AN>Männer</AN>      <RN>Aktivist*innen</RN>     True       53.0
# 31    C5   <AN>Männer</AN>  <RN>Arbeitnehmer*innen</RN>     True       53.0
# 34    C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>     True       53.0
# 36    C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>     True       53.0
# 38    C5   <AN>Männer</AN>     <RN>Ingenieur*innen</RN>     True       53.0
# 40    C3   <AN>Männer</AN>      <RN>Professorinnen</RN>     True       53.0
# 43    C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>     True       53.0
# 47    C1  <AN>Männern</AN>           <RN>Einwohner</RN>     True       53.0
# ...

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

# Nach Code sortieren
trial_data_auswahl = trial_data_auswahl.sort_values(by="Code")

display(trial_data_auswahl)
# Out:
#     Code                AN                           RN an_found  an_height  \
# 95    C1   <AN>Männer</AN>            <RN>Experten</RN>     True       53.0
# 47    C1  <AN>Männern</AN>           <RN>Einwohner</RN>     True       53.0
# 101   C1   <AN>Männer</AN>           <RN>Studenten</RN>     True       53.0
# 7     C2   <AN>Frauen</AN>            <RN>Experten</RN>     True       53.0
# 96    C2   <AN>Frauen</AN>             <RN>Pfleger</RN>     True       53.0
# 16    C2   <AN>Frauen</AN>           <RN>Einwohner</RN>     True       53.0
# 80    C3   <AN>Männer</AN>      <RN>Ingenieurinnen</RN>     True       53.0
# 43    C3   <AN>Männer</AN>         <RN>Dozentinnen</RN>     True       53.0
# 40    C3   <AN>Männer</AN>      <RN>Professorinnen</RN>     True       53.0
# 36    C4   <AN>Frauen</AN>         <RN>Expertinnen</RN>     True       53.0
# 34    C4   <AN>Frauen</AN>   <RN>Krankenschwestern</RN>     True       53.0
# ...
