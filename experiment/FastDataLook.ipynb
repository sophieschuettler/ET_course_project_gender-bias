# %%
import pandas as pd


csv_path = "subject-4.csv"

trial_data = pd.read_csv(csv_path)

# %%
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]
display(trial_data_gezeigt)
# Out:
#                   AN Code                             RN        acc  \
# 5    <AN>Frauen</AN>   C6     <RN>Unternehmer*innen</RN>  undefined
# 9    <AN>Frauen</AN>   C6          <RN>Expert*innen</RN>  undefined
# 32   <AN>Männer</AN>   C5       <RN>Professor*innen</RN>  undefined
# 34   <AN>Männer</AN>   C1          <RN>Arbeitnehmer</RN>  undefined
# 41   <AN>Männer</AN>   C1            <RN>Aktivisten</RN>  undefined
# 42   <AN>Frauen</AN>   C4           <RN>Expertinnen</RN>  undefined
# 43   <AN>Männer</AN>   C3          <RN>Studentinnen</RN>  undefined
# 57   <AN>Männer</AN>   C5          <RN>Dozent*innen</RN>  undefined
# 58   <AN>Frauen</AN>   C6  <RN>Krankenpfleger*innen</RN>  undefined
# 59   <AN>Frauen</AN>   C4        <RN>Einwohnerinnen</RN>  undefined
# 67   <AN>Männer</AN>   C3           <RN>Expertinnen</RN>  undefined
# 71   <AN>Frauen</AN>   C2            <RN>Polizisten</RN>  undefined
# 73   <AN>Frauen</AN>   C4          <RN>Pflegerinnen</RN>  undefined
# 79   <AN>Frauen</AN>   C2                <RN>Lehrer</RN>  undefined
# 80  <AN>Männern</AN>   C3        <RN>Einwohnerinnen</RN>  undefined
# 88   <AN>Frauen</AN>   C2          <RN>Arbeitnehmer</RN>  undefined
# 94   <AN>Männer</AN>   C5       <RN>Ingenieur*innen</RN>  undefined
# 97   <AN>Männer</AN>   C1            <RN>Ingenieure</RN>  undefined
#
#      accuracy an_found  an_height  an_line           an_text  an_width  ...  \
# 5   undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 9   undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 32  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 34  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 41  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 42  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 43  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 57  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 58  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 59  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 67  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 71  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 73  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 79  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 80  undefined     True       53.0      4.0  <AN>Männern</AN>     158.0  ...
# 88  undefined     True       53.0      4.0   <AN>Frauen</AN>     132.0  ...
# 94  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
# 97  undefined     True       53.0      4.0   <AN>Männer</AN>     135.0  ...
#
#          title  total_correct  total_response_time  total_responses  \
# 5   Experiment              0                    0                0
# 9   Experiment              0                    0                0
# 32  Experiment              0                    0                0
# 34  Experiment              0                    0                0
# 41  Experiment              0                    0                0
# 42  Experiment              0                    0                0
# 43  Experiment              0                    0                0
# 57  Experiment              0                    0                0
# 58  Experiment              0                    0                0
# 59  Experiment              0                    0                0
# 67  Experiment              0                    0                0
# 71  Experiment              0                    0                0
# 73  Experiment              0                    0                0
# 79  Experiment              0                    0                0
# 80  Experiment              0                    0                0
# 88  Experiment              0                    0                0
# 94  Experiment              0                    0                0
# 97  Experiment              0                    0                0
#
#    trial_counter width           word  word_height word_spacing word_width
# 5              1  1920    umstritten.         53.0         25.0      243.0
# 9              2  1920       geprüft.         53.0         25.0      175.0
# 32             3  1920    diskutiert.         53.0         25.0      243.0
# 34             4  1920         offen.         53.0         25.0      129.0
# 41             5  1920       geprüft.         53.0         25.0      175.0
# 42             6  1920      bewertet.         53.0         25.0      197.0
# 43             7  1920      Debatten.         53.0         25.0      197.0
# 57             8  1920            an.         53.0         25.0       59.0
# 58             9  1920    diskutiert.         53.0         25.0      243.0
# 59            10  1920    Reaktionen.         53.0         25.0      242.0
# 67            11  1920      bewertet.         53.0         25.0      197.0
# 71            12  1920    verhandelt.         53.0         25.0      244.0
# 73            13  1920    diskutiert.         53.0         25.0      243.0
# 79            14  1920  Diskussionen.         53.0         25.0      289.0
# 80            15  1920      Debatten.         53.0         25.0      197.0
# 88            16  1920  Diskussionen.         53.0         25.0      289.0
# 94            17  1920    gestritten.         53.0         25.0      244.0
# 97            18  1920    diskutiert.         53.0         25.0      243.0
#
# [18 rows x 150 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Gewünschte Spalten
spalten = [
    "Code","AN", "RN",
    "an_found", "an_height", "an_line", "an_width",
    "an_x1", "an_x2",
    "current_line", "current_line_width",
    "datetime",
    "display_sentence",
    "experiment_file", "experiment_path",
    "item",
    "name",
    "rn_found", "rn_height", "rn_line", "rn_text",
    "rn_width", "rn_x1", "rn_x2", "rn_y1", "rn_y2",
    "selected_list",
    "skip_trial",
    "spill_x1", "spill_x2", "spill_y1", "spill_y2",
    "trial_counter"
]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

display(trial_data_auswahl)
# Out:
#    Code                AN                             RN an_found  an_height  \
# 5    C6   <AN>Frauen</AN>     <RN>Unternehmer*innen</RN>     True       53.0
# 9    C6   <AN>Frauen</AN>          <RN>Expert*innen</RN>     True       53.0
# 32   C5   <AN>Männer</AN>       <RN>Professor*innen</RN>     True       53.0
# 34   C1   <AN>Männer</AN>          <RN>Arbeitnehmer</RN>     True       53.0
# 41   C1   <AN>Männer</AN>            <RN>Aktivisten</RN>     True       53.0
# 42   C4   <AN>Frauen</AN>           <RN>Expertinnen</RN>     True       53.0
# 43   C3   <AN>Männer</AN>          <RN>Studentinnen</RN>     True       53.0
# 57   C5   <AN>Männer</AN>          <RN>Dozent*innen</RN>     True       53.0
# 58   C6   <AN>Frauen</AN>  <RN>Krankenpfleger*innen</RN>     True       53.0
# 59   C4   <AN>Frauen</AN>        <RN>Einwohnerinnen</RN>     True       53.0
# 67   C3   <AN>Männer</AN>           <RN>Expertinnen</RN>     True       53.0
# 71   C2   <AN>Frauen</AN>            <RN>Polizisten</RN>     True       53.0
# 73   C4   <AN>Frauen</AN>          <RN>Pflegerinnen</RN>     True       53.0
# 79   C2   <AN>Frauen</AN>                <RN>Lehrer</RN>     True       53.0
# 80   C3  <AN>Männern</AN>        <RN>Einwohnerinnen</RN>     True       53.0
# 88   C2   <AN>Frauen</AN>          <RN>Arbeitnehmer</RN>     True       53.0
# 94   C5   <AN>Männer</AN>       <RN>Ingenieur*innen</RN>     True       53.0
# 97   C1   <AN>Männer</AN>            <RN>Ingenieure</RN>     True       53.0
#
#     an_line  an_width  an_x1  an_x2  current_line  ...  rn_x2  rn_y1  rn_y2  \
# 5       4.0     132.0  -84.0   48.0           5.0  ... -423.0  -56.0   -3.0
# 9       4.0     132.0  -63.0   69.0           5.0  ... -380.0  -56.0   -3.0
# 32      4.0     135.0  -65.0   70.0           5.0  ...  801.0 -173.0 -120.0
# 34      4.0     135.0 -305.0 -170.0           5.0  ... -536.0  -56.0   -3.0
# 41      4.0     135.0 -201.0  -66.0           5.0  ...  489.0 -173.0 -120.0
# 42      4.0     132.0 -223.0  -91.0           5.0  ... -562.0  -56.0   -3.0
# 43      4.0     135.0 -219.0  -84.0           5.0  ...  602.0 -173.0 -120.0
# 57      4.0     135.0 -339.0 -204.0           5.0  ...  760.0 -173.0 -120.0
# 58      4.0     132.0  -17.0  115.0           5.0  ... -355.0  -56.0   -3.0
# 59      4.0     132.0  -89.0   43.0           5.0  ... -493.0  -56.0   -3.0
# 67      4.0     135.0 -309.0 -174.0           5.0  ... -562.0  -56.0   -3.0
# 71      4.0     132.0 -202.0  -70.0           5.0  ...  212.0 -173.0 -120.0
# 73      4.0     132.0 -222.0  -90.0           6.0  ... -539.0  -56.0   -3.0
# 79      4.0     132.0 -333.0 -201.0           5.0  ...  299.0 -173.0 -120.0
# 80      4.0     158.0 -309.0 -151.0           5.0  ... -493.0  -56.0   -3.0
# 88      4.0     132.0 -329.0 -197.0           5.0  ...  788.0 -173.0 -120.0
# 94      4.0     135.0 -130.0    5.0           5.0  ... -471.0  -56.0   -3.0
# 97      4.0     135.0 -335.0 -200.0           5.0  ...  705.0 -173.0 -120.0
#
#    selected_list skip_trial  spill_x1 spill_x2 spill_y1  spill_y2  \
# 5              3          0      48.0    180.0     61.0     114.0
# 9              3          0      69.0    201.0     61.0     114.0
# 32             3          0      70.0    205.0     61.0     114.0
# 34             3          0    -170.0    -35.0     61.0     114.0
# 41             3          0     -66.0     69.0     61.0     114.0
# 42             3          0     -91.0     41.0     61.0     114.0
# 43             3          0     -84.0     51.0     61.0     114.0
# 57             3          0    -204.0    -69.0     61.0     114.0
# 58             3          0     115.0    247.0     61.0     114.0
# 59             3          0      43.0    175.0     61.0     114.0
# 67             3          0    -174.0    -39.0     61.0     114.0
# 71             3          0     -70.0     62.0     61.0     114.0
# 73             3          0     -90.0     42.0     61.0     114.0
# 79             3          0    -201.0    -69.0     61.0     114.0
# 80             3          0    -151.0      7.0     61.0     114.0
# 88             3          0    -197.0    -65.0     61.0     114.0
# 94             3          0       5.0    140.0     61.0     114.0
# 97             3          0    -200.0    -65.0     61.0     114.0
#
#     trial_counter
# 5               1
# 9               2
# 32              3
# 34              4
# 41              5
# 42              6
# 43              7
# 57              8
# 58              9
# 59             10
# 67             11
# 71             12
# 73             13
# 79             14
# 80             15
# 88             16
# 94             17
# 97             18
#
# [18 rows x 33 columns]

# %%
# Nur gezeigte Trials
trial_data_gezeigt = trial_data[trial_data["skip_trial"] == 0]

# Tabelle erzeugen
trial_data_auswahl = trial_data_gezeigt[spalten]

# Nach Code sortieren
trial_data_auswahl = trial_data_auswahl.sort_values(by="Code")

display(trial_data_auswahl)
# Out:
#    Code                AN                             RN an_found  an_height  \
# 97   C1   <AN>Männer</AN>            <RN>Ingenieure</RN>     True       53.0
# 34   C1   <AN>Männer</AN>          <RN>Arbeitnehmer</RN>     True       53.0
# 41   C1   <AN>Männer</AN>            <RN>Aktivisten</RN>     True       53.0
# 88   C2   <AN>Frauen</AN>          <RN>Arbeitnehmer</RN>     True       53.0
# 71   C2   <AN>Frauen</AN>            <RN>Polizisten</RN>     True       53.0
# 79   C2   <AN>Frauen</AN>                <RN>Lehrer</RN>     True       53.0
# 43   C3   <AN>Männer</AN>          <RN>Studentinnen</RN>     True       53.0
# 67   C3   <AN>Männer</AN>           <RN>Expertinnen</RN>     True       53.0
# 80   C3  <AN>Männern</AN>        <RN>Einwohnerinnen</RN>     True       53.0
# 42   C4   <AN>Frauen</AN>           <RN>Expertinnen</RN>     True       53.0
# 59   C4   <AN>Frauen</AN>        <RN>Einwohnerinnen</RN>     True       53.0
# 73   C4   <AN>Frauen</AN>          <RN>Pflegerinnen</RN>     True       53.0
# 32   C5   <AN>Männer</AN>       <RN>Professor*innen</RN>     True       53.0
# 57   C5   <AN>Männer</AN>          <RN>Dozent*innen</RN>     True       53.0
# 94   C5   <AN>Männer</AN>       <RN>Ingenieur*innen</RN>     True       53.0
# 5    C6   <AN>Frauen</AN>     <RN>Unternehmer*innen</RN>     True       53.0
# 9    C6   <AN>Frauen</AN>          <RN>Expert*innen</RN>     True       53.0
# 58   C6   <AN>Frauen</AN>  <RN>Krankenpfleger*innen</RN>     True       53.0
#
#     an_line  an_width  an_x1  an_x2  current_line  ...  rn_x2  rn_y1  rn_y2  \
# 97      4.0     135.0 -335.0 -200.0           5.0  ...  705.0 -173.0 -120.0
# 34      4.0     135.0 -305.0 -170.0           5.0  ... -536.0  -56.0   -3.0
# 41      4.0     135.0 -201.0  -66.0           5.0  ...  489.0 -173.0 -120.0
# 88      4.0     132.0 -329.0 -197.0           5.0  ...  788.0 -173.0 -120.0
# 71      4.0     132.0 -202.0  -70.0           5.0  ...  212.0 -173.0 -120.0
# 79      4.0     132.0 -333.0 -201.0           5.0  ...  299.0 -173.0 -120.0
# 43      4.0     135.0 -219.0  -84.0           5.0  ...  602.0 -173.0 -120.0
# 67      4.0     135.0 -309.0 -174.0           5.0  ... -562.0  -56.0   -3.0
# 80      4.0     158.0 -309.0 -151.0           5.0  ... -493.0  -56.0   -3.0
# 42      4.0     132.0 -223.0  -91.0           5.0  ... -562.0  -56.0   -3.0
# 59      4.0     132.0  -89.0   43.0           5.0  ... -493.0  -56.0   -3.0
# 73      4.0     132.0 -222.0  -90.0           6.0  ... -539.0  -56.0   -3.0
# 32      4.0     135.0  -65.0   70.0           5.0  ...  801.0 -173.0 -120.0
# 57      4.0     135.0 -339.0 -204.0           5.0  ...  760.0 -173.0 -120.0
# 94      4.0     135.0 -130.0    5.0           5.0  ... -471.0  -56.0   -3.0
# 5       4.0     132.0  -84.0   48.0           5.0  ... -423.0  -56.0   -3.0
# 9       4.0     132.0  -63.0   69.0           5.0  ... -380.0  -56.0   -3.0
# 58      4.0     132.0  -17.0  115.0           5.0  ... -355.0  -56.0   -3.0
#
#    selected_list skip_trial  spill_x1 spill_x2 spill_y1  spill_y2  \
# 97             3          0    -200.0    -65.0     61.0     114.0
# 34             3          0    -170.0    -35.0     61.0     114.0
# 41             3          0     -66.0     69.0     61.0     114.0
# 88             3          0    -197.0    -65.0     61.0     114.0
# 71             3          0     -70.0     62.0     61.0     114.0
# 79             3          0    -201.0    -69.0     61.0     114.0
# 43             3          0     -84.0     51.0     61.0     114.0
# 67             3          0    -174.0    -39.0     61.0     114.0
# 80             3          0    -151.0      7.0     61.0     114.0
# 42             3          0     -91.0     41.0     61.0     114.0
# 59             3          0      43.0    175.0     61.0     114.0
# 73             3          0     -90.0     42.0     61.0     114.0
# 32             3          0      70.0    205.0     61.0     114.0
# 57             3          0    -204.0    -69.0     61.0     114.0
# 94             3          0       5.0    140.0     61.0     114.0
# 5              3          0      48.0    180.0     61.0     114.0
# 9              3          0      69.0    201.0     61.0     114.0
# 58             3          0     115.0    247.0     61.0     114.0
#
#     trial_counter
# 97             18
# 34              4
# 41              5
# 88             16
# 71             12
# 79             14
# 43              7
# 67             11
# 80             15
# 42              6
# 59             10
# 73             13
# 32              3
# 57              8
# 94             17
# 5               1
# 9               2
# 58              9
#
# [18 rows x 33 columns]
